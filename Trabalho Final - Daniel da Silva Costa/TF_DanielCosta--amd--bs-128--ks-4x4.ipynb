# %%
# from google.colab import drive
# drive.mount('/content/drive', force_remount=True)

# %%
# cd "drive/MyDrive/Doutorado/Disciplinas/[2022.2] [PUC-Rio] Visão Computacional - Professor: Marcelo Gattass/Trabalhos/Trabalho Final/Code/What does a CNN see?/"

# %%
# !pwd

# %%
data_folder = './data/'

# %% [markdown]
# # Imports

# %%
import os
import cv2
import glob
import imgaug as aug
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import imgaug.augmenters as iaa
from os import listdir
from pathlib import Path
from keras.models import Sequential, Model
# from keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from keras.callbacks import ModelCheckpoint, EarlyStopping
# from keras.utils import to_categorical
from tensorflow.keras.utils import to_categorical
from keras import backend as K
from keras.applications.vgg16 import preprocess_input
import tensorflow as tf
tf.compat.v1.disable_eager_execution()


color = sns.color_palette()
# %matplotlib inline
# %config InlineBackend.figure_format="svg"

# Daniel
from tensorflow.keras import layers, models

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
print(tf.__version__)
# Out:
# 2.6.0

# %% [markdown]
# # Seed

# %%
# Set the seed for hash based operations in python
os.environ['PYTHONHASHSEED'] = '0'

seed=1234

# Set the numpy seed
np.random.seed(seed)

# Set the random seed in tensorflow at graph level
# tf.set_random_seed(seed) # obsolete
tf.random.set_seed(seed)

# Make the augmentation sequence deterministic
aug.seed(seed)

# %%
# As usual, define some paths first to make life simpler
training_data = Path(data_folder + '/training/') 
validation_data = Path(data_folder + '/validation/') 
labels_path = Path(data_folder + '/monkey_labels.txt')

# %%
labels_info = []

# Read the file
lines = labels_path.read_text().strip().splitlines()[1:]
for line in lines:
    line = line.split(',')
    line = [x.strip(' \n\t\r') for x in line]
    line[3], line[4] = int(line[3]), int(line[4])
    line = tuple(line)
    labels_info.append(line)
    
# Convert the data into a pandas dataframe
labels_info = pd.DataFrame(labels_info, columns=['Label', 'Latin Name', 'Common Name', 
                                                 'Train Images', 'Validation Images'], index=None)
# Sneak peek 
labels_info.head(10)
# Out:
#   Label             Latin Name                Common Name  Train Images  \
# 0    n0      alouatta_palliata             mantled_howler           131
# 1    n1     erythrocebus_patas               patas_monkey           139
# 2    n2         cacajao_calvus                bald_uakari           137
# 3    n3         macaca_fuscata           japanese_macaque           152
# 4    n4        cebuella_pygmea             pygmy_marmoset           131
# 5    n5        cebus_capucinus      white_headed_capuchin           141
# 6    n6        mico_argentatus           silvery_marmoset           132
# 7    n7       saimiri_sciureus     common_squirrel_monkey           142
# 8    n8        aotus_nigriceps  black_headed_night_monkey           133
# 9    n9  trachypithecus_johnii             nilgiri_langur           132
#
#    Validation Images
# 0                 26
# 1                 28
# 2                 27
# 3                 30
# 4                 26
# 5                 28
# 6                 26
# 7                 28
# 8                 27
# 9                 26

# %%
# Create a dictionary to map the labels to integers
labels_dict= {'n0':0, 'n1':1, 'n2':2, 'n3':3, 'n4':4, 'n5':5, 'n6':6, 'n7':7, 'n8':8, 'n9':9}

# map labels to common names
names_dict = dict(zip(labels_dict.values(), labels_info["Common Name"]))
print(names_dict)
# Out:
# {0: 'mantled_howler', 1: 'patas_monkey', 2: 'bald_uakari', 3: 'japanese_macaque', 4: 'pygmy_marmoset', 5: 'white_headed_capuchin', 6: 'silvery_marmoset', 7: 'common_squirrel_monkey', 8: 'black_headed_night_monkey', 9: 'nilgiri_langur'}

# %%
# Creating a dataframe for the training dataset
train_df = []
for folder in os.listdir(training_data):
    # Define the path to the images
    imgs_path = training_data / folder
    
    # Get the list of all the images stored in that directory
    imgs = sorted(imgs_path.glob('*.jpg'))
    
    # Store each image path and corresponding label 
    for img_name in imgs:
        train_df.append((str(img_name), labels_dict[folder]))


train_df = pd.DataFrame(train_df, columns=['image', 'label'], index=None)
# shuffle the dataset 
train_df = train_df.sample(frac=1.).reset_index(drop=True)

####################################################################################################

# Creating dataframe for validation data in a similar fashion
valid_df = []
for folder in os.listdir(validation_data):
    imgs_path = validation_data / folder
    imgs = sorted(imgs_path.glob('*.jpg'))
    for img_name in imgs:
        valid_df.append((str(img_name), labels_dict[folder]))

        
valid_df = pd.DataFrame(valid_df, columns=['image', 'label'], index=None)
# shuffle the dataset 
valid_df = valid_df.sample(frac=1.).reset_index(drop=True)

####################################################################################################

# How many samples do we have in our training and validation data?
print("Number of traininng samples: ", len(train_df))
print("Number of validation samples: ", len(valid_df))

# sneak peek of the training and validation dataframes
print("\n",train_df.head(), "\n")
print("=================================================================\n")
print("\n", valid_df.head())
# Out:
# Number of traininng samples:  1097
# Number of validation samples:  272
#
#                          image  label
# 0  data\training\n0\n0134.jpg      0
# 1  data\training\n4\n4114.jpg      4
# 2  data\training\n4\n4059.jpg      4
# 3  data\training\n3\n3061.jpg      3
# 4  data\training\n0\n0150.jpg      0
#
# =================================================================
#
#
#                            image  label
# 0   data\validation\n2\n218.jpg      2
# 1  data\validation\n3\n3013.jpg      3
# 2  data\validation\n2\n2011.jpg      2
# 3   data\validation\n6\n608.jpg      6
# 4   data\validation\n6\n605.jpg      6

# %% [markdown]
# # batch_size

# %%
batch_size=128

# %%
# some constants(not truly though!) 

# dimensions to consider for the images
img_rows, img_cols, img_channels = 224,224,3

# total number of classes in the dataset
nb_classes=10

# %%
# Augmentation sequence 
seq = iaa.OneOf([
    iaa.Fliplr(), # horizontal flips
    iaa.Affine(rotate=20), # roatation
    iaa.Multiply((1.2, 1.5))]) #random brightness

# %%
def data_generator(data, batch_size, is_validation_data=False):
    # Get total number of samples in the data
    n = len(data)
    nb_batches = int(np.ceil(n/batch_size))

    # Get a numpy array of all the indices of the input data
    indices = np.arange(n)
    
    # Define two numpy arrays for containing batch data and labels
    batch_data = np.zeros((batch_size, img_rows, img_cols, img_channels), dtype=np.float32)
    batch_labels = np.zeros((batch_size, nb_classes), dtype=np.float32)
    
    while True:
        if not is_validation_data:
            # shuffle indices for the training data
            np.random.shuffle(indices)
            
        for i in range(nb_batches):
            # get the next batch 
            next_batch_indices = indices[i*batch_size:(i+1)*batch_size]
            
            # process the next batch
            for j, idx in enumerate(next_batch_indices):
                img = cv2.imread(data.iloc[idx]["image"])
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                label = data.iloc[idx]["label"]
                
                if not is_validation_data:
                    img = seq.augment_image(img)
                
                img = cv2.resize(img, (img_rows, img_cols)).astype(np.float32)
                batch_data[j] = img
                batch_labels[j] = to_categorical(label,num_classes=nb_classes)
            
            batch_data = preprocess_input(batch_data)
            yield batch_data, batch_labels

# %%
#training data generator 
train_data_gen = data_generator(train_df, batch_size)

# validation data generator 
valid_data_gen = data_generator(valid_df, batch_size, is_validation_data=True)

# %% [markdown]
# # kernel_size

# %%
kernel_size = 4

# %%
# https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D
# tf.keras.layers.Conv2D( filters, kernel_size, ...)

model = models.Sequential([
    layers.InputLayer( input_shape=(224, 224, 3) )
])

### 1 conv layer
model.add( layers.Conv2D(16, (kernel_size, kernel_size), 
                        padding='same',
                        activation='relu') )
model.add( layers.MaxPooling2D((2, 2)) )

### 2 conv layer
model.add( layers.Conv2D(32, (kernel_size, kernel_size), 
                        padding='same',
                        activation='relu') )
model.add( layers.MaxPooling2D((2, 2)) )

### 3 conv layer
model.add( layers.Conv2D(64, (kernel_size, kernel_size), 
                        padding='same',
                        activation='relu') )
model.add( layers.MaxPooling2D((2, 2)) )

### 4 conv layer
model.add( layers.Conv2D(128, (kernel_size, kernel_size), 
                        padding='same',
                        activation='relu') )
model.add( layers.MaxPooling2D((2, 2)) )

### 5 conv layer
model.add( layers.Conv2D(256, (kernel_size, kernel_size), 
                        padding='same',
                        activation='relu') )
model.add( layers.MaxPooling2D((2, 2)) )

### 6 fully layers
model.add( layers.Flatten() )
model.add( layers.Dense(4096, activation='relu') )
model.add( layers.Dense(4096, activation='relu') )
model.add( layers.Dropout(0.2) )
model.add( layers.Dense(10, activation='softmax') )

# To correct some bug on input
model = Model(model.input, model.output)

optimizer = RMSprop(0.001)
model.compile(optimizer = optimizer, 
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 224, 224, 16)      784
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 32)      8224
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 56, 56, 64)        32832
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 128)       131200
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 14, 14, 256)       524544
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 12544)             0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              51384320
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                40970
# =================================================================
# Total params: 68,904,186
# Trainable params: 68,904,186
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stopping = EarlyStopping(patience=20, restore_best_weights=True)

model_checkpoint = ModelCheckpoint(filepath="model1", save_best_only=True)

num_train_steps = int(np.ceil(len(train_df)/batch_size))
num_valid_steps = int(np.ceil(len(valid_df)/batch_size))

# %%
epochs=100
# epochs=5 # daniel

# %% [markdown]
# # Training

# %%
# %%time

history1 = model.fit(train_data_gen, 
                              epochs = epochs, 
                              steps_per_epoch = num_train_steps, 
                              validation_data = valid_data_gen, 
                              validation_steps = num_valid_steps,
                              callbacks = [early_stopping, model_checkpoint])
# Out:
# Epoch 1/100
# 9/9 [==============================] - ETA: 0s - batch: 4.0000 - size: 128.0000 - loss: 1710.6396 - accuracy: 0.0938
# C:\Users\danie\anaconda3\envs\tf\lib\site-packages\keras\engine\training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# INFO:tensorflow:Assets written to: model1\assets
# 9/9 [==============================] - 38s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 1710.6396 - accuracy: 0.0938 - val_loss: 2.3256 - val_accuracy: 0.1432
# Epoch 2/100
# 9/9 [==============================] - 24s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 2.3298 - accuracy: 0.1667 - val_loss: 2.6785 - val_accuracy: 0.0885
# Epoch 3/100
# 9/9 [==============================] - ETA: 0s - batch: 4.0000 - size: 128.0000 - loss: 2.3018 - accuracy: 0.1753INFO:tensorflow:Assets written to: model1\assets
# 9/9 [==============================] - 31s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 2.3018 - accuracy: 0.1753 - val_loss: 2.2555 - val_accuracy: 0.1667
# Epoch 4/100
# 9/9 [==============================] - 24s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 2.1722 - accuracy: 0.2240 - val_loss: 2.2698 - val_accuracy: 0.1224
# Epoch 5/100
# 9/9 [==============================] - ETA: 0s - batch: 4.0000 - size: 128.0000 - loss: 2.5343 - accuracy: 0.1545INFO:tensorflow:Assets written to: model1\assets
# 9/9 [==============================] - 31s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 2.5343 - accuracy: 0.1545 - val_loss: 2.2000 - val_accuracy: 0.1589
# Epoch 6/100
# 9/9 [==============================] - 24s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 2.4017 - accuracy: 0.1667 - val_loss: 2.2799 - val_accuracy: 0.1302
# Epoch 7/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 2.2080 - accuracy: 0.2153 - val_loss: 2.3366 - val_accuracy: 0.1432
# Epoch 8/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 2.2289 - accuracy: 0.2101 - val_loss: 2.3003 - val_accuracy: 0.1823
# Epoch 9/100
# 9/9 [==============================] - ETA: 0s - batch: 4.0000 - size: 128.0000 - loss: 2.5016 - accuracy: 0.1988INFO:tensorflow:Assets written to: model1\assets
# 9/9 [==============================] - 31s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 2.5016 - accuracy: 0.1988 - val_loss: 2.1906 - val_accuracy: 0.1901
# Epoch 10/100
# 9/9 [==============================] - ETA: 0s - batch: 4.0000 - size: 128.0000 - loss: 2.0856 - accuracy: 0.2717INFO:tensorflow:Assets written to: model1\assets
# 9/9 [==============================] - 28s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 2.0856 - accuracy: 0.2717 - val_loss: 2.1693 - val_accuracy: 0.2188
# Epoch 11/100
# 9/9 [==============================] - 24s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 2.3250 - accuracy: 0.2535 - val_loss: 2.7224 - val_accuracy: 0.1875
# Epoch 12/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 2.4506 - accuracy: 0.1875 - val_loss: 2.2085 - val_accuracy: 0.2109
# Epoch 13/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 2.2482 - accuracy: 0.2205 - val_loss: 4.1928 - val_accuracy: 0.0990
# Epoch 14/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 2.5066 - accuracy: 0.1502 - val_loss: 2.1734 - val_accuracy: 0.1979
# Epoch 15/100
# 9/9 [==============================] - 28s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 2.7031 - accuracy: 0.2049 - val_loss: 3.3888 - val_accuracy: 0.1250
# Epoch 16/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 2.7829 - accuracy: 0.1684 - val_loss: 2.3386 - val_accuracy: 0.2135
# Epoch 17/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 2.1063 - accuracy: 0.2127 - val_loss: 2.3443 - val_accuracy: 0.1432
# Epoch 18/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 2.4195 - accuracy: 0.2075 - val_loss: 2.6662 - val_accuracy: 0.1172
# Epoch 19/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 2.1858 - accuracy: 0.2326 - val_loss: 2.3408 - val_accuracy: 0.1406
# Epoch 20/100
# 9/9 [==============================] - ETA: 0s - batch: 4.0000 - size: 128.0000 - loss: 2.1109 - accuracy: 0.2413INFO:tensorflow:Assets written to: model1\assets
# 9/9 [==============================] - 31s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 2.1109 - accuracy: 0.2413 - val_loss: 2.0733 - val_accuracy: 0.2370
# Epoch 21/100
# 9/9 [==============================] - 24s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 2.0557 - accuracy: 0.2977 - val_loss: 2.5273 - val_accuracy: 0.2135
# Epoch 22/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 2.4125 - accuracy: 0.2257 - val_loss: 2.1064 - val_accuracy: 0.2083
# Epoch 23/100
# 9/9 [==============================] - ETA: 0s - batch: 4.0000 - size: 128.0000 - loss: 1.9460 - accuracy: 0.2995INFO:tensorflow:Assets written to: model1\assets
# 9/9 [==============================] - 40s 5s/step - batch: 4.0000 - size: 128.0000 - loss: 1.9460 - accuracy: 0.2995 - val_loss: 2.0421 - val_accuracy: 0.2500
# Epoch 24/100
# 9/9 [==============================] - 15s 2s/step - batch: 4.0000 - size: 128.0000 - loss: 2.2283 - accuracy: 0.2925 - val_loss: 2.1223 - val_accuracy: 0.2344
# Epoch 25/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 2.0593 - accuracy: 0.2587 - val_loss: 3.9115 - val_accuracy: 0.1172
# Epoch 26/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 2.5601 - accuracy: 0.2300 - val_loss: 2.1258 - val_accuracy: 0.2109
# Epoch 27/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 2.1901 - accuracy: 0.2196 - val_loss: 2.1070 - val_accuracy: 0.2240
# Epoch 28/100
# 9/9 [==============================] - ETA: 0s - batch: 4.0000 - size: 128.0000 - loss: 2.0014 - accuracy: 0.2795INFO:tensorflow:Assets written to: model1\assets
# 9/9 [==============================] - 31s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 2.0014 - accuracy: 0.2795 - val_loss: 2.0218 - val_accuracy: 0.2630
# Epoch 29/100
# 9/9 [==============================] - 25s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 1.9962 - accuracy: 0.3047 - val_loss: 2.5055 - val_accuracy: 0.1380
# Epoch 30/100
# 9/9 [==============================] - ETA: 0s - batch: 4.0000 - size: 128.0000 - loss: 2.1237 - accuracy: 0.2240INFO:tensorflow:Assets written to: model1\assets
# 9/9 [==============================] - 31s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 2.1237 - accuracy: 0.2240 - val_loss: 1.9584 - val_accuracy: 0.2734
# Epoch 31/100
# 9/9 [==============================] - 24s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 1.9258 - accuracy: 0.3247 - val_loss: 2.1552 - val_accuracy: 0.1953
# Epoch 32/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 2.0050 - accuracy: 0.3142 - val_loss: 2.2574 - val_accuracy: 0.2005
# Epoch 33/100
# 9/9 [==============================] - ETA: 0s - batch: 4.0000 - size: 128.0000 - loss: 2.0155 - accuracy: 0.2943INFO:tensorflow:Assets written to: model1\assets
# 9/9 [==============================] - 31s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 2.0155 - accuracy: 0.2943 - val_loss: 1.7928 - val_accuracy: 0.3229
# Epoch 34/100
# 9/9 [==============================] - 24s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 1.8620 - accuracy: 0.3628 - val_loss: 2.1877 - val_accuracy: 0.1979
# Epoch 35/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 1.9616 - accuracy: 0.3099 - val_loss: 2.5464 - val_accuracy: 0.1693
# Epoch 36/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 2.4408 - accuracy: 0.2648 - val_loss: 2.1585 - val_accuracy: 0.2083
# Epoch 37/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 1.7661 - accuracy: 0.3663 - val_loss: 1.9027 - val_accuracy: 0.3229
# Epoch 38/100
# 9/9 [==============================] - 28s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 2.0213 - accuracy: 0.3420 - val_loss: 2.4318 - val_accuracy: 0.1562
# Epoch 39/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 1.9372 - accuracy: 0.3438 - val_loss: 1.8673 - val_accuracy: 0.3099
# Epoch 40/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 1.6147 - accuracy: 0.4288 - val_loss: 1.8991 - val_accuracy: 0.3464
# Epoch 41/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 1.8637 - accuracy: 0.4045 - val_loss: 2.1442 - val_accuracy: 0.2240
# Epoch 42/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 1.7090 - accuracy: 0.3967 - val_loss: 2.7850 - val_accuracy: 0.3255
# Epoch 43/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 1.8092 - accuracy: 0.4262 - val_loss: 1.8773 - val_accuracy: 0.4167
# Epoch 44/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 1.5767 - accuracy: 0.4575 - val_loss: 1.8308 - val_accuracy: 0.3698
# Epoch 45/100
# 9/9 [==============================] - ETA: 0s - batch: 4.0000 - size: 128.0000 - loss: 1.6398 - accuracy: 0.4635INFO:tensorflow:Assets written to: model1\assets
# 9/9 [==============================] - 31s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 1.6398 - accuracy: 0.4635 - val_loss: 1.6725 - val_accuracy: 0.4115
# Epoch 46/100
# 9/9 [==============================] - ETA: 0s - batch: 4.0000 - size: 128.0000 - loss: 1.5703 - accuracy: 0.4583INFO:tensorflow:Assets written to: model1\assets
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 1.5703 - accuracy: 0.4583 - val_loss: 1.5926 - val_accuracy: 0.4661
# Epoch 47/100
# 9/9 [==============================] - 24s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 1.5961 - accuracy: 0.4479 - val_loss: 1.8101 - val_accuracy: 0.3281
# Epoch 48/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 1.3614 - accuracy: 0.5477 - val_loss: 1.6841 - val_accuracy: 0.3958
# Epoch 49/100
# 9/9 [==============================] - ETA: 0s - batch: 4.0000 - size: 128.0000 - loss: 1.2636 - accuracy: 0.5773INFO:tensorflow:Assets written to: model1\assets
# 9/9 [==============================] - 30s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 1.2636 - accuracy: 0.5773 - val_loss: 1.5428 - val_accuracy: 0.4818
# Epoch 50/100
# 9/9 [==============================] - 24s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 2.5987 - accuracy: 0.4444 - val_loss: 1.7437 - val_accuracy: 0.3724
# Epoch 51/100
# 9/9 [==============================] - 28s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 1.4853 - accuracy: 0.4887 - val_loss: 1.7818 - val_accuracy: 0.3932
# Epoch 52/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 1.3084 - accuracy: 0.5425 - val_loss: 1.6295 - val_accuracy: 0.4193
# Epoch 53/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 1.0428 - accuracy: 0.6476 - val_loss: 1.7429 - val_accuracy: 0.4453
# Epoch 54/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 1.3986 - accuracy: 0.5174 - val_loss: 1.6572 - val_accuracy: 0.4167
# Epoch 55/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 1.0454 - accuracy: 0.6615 - val_loss: 2.8580 - val_accuracy: 0.3490
# Epoch 56/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 1.6968 - accuracy: 0.5035 - val_loss: 1.6436 - val_accuracy: 0.4531
# Epoch 57/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 0.8654 - accuracy: 0.7257 - val_loss: 2.1593 - val_accuracy: 0.4401
# Epoch 58/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 1.0993 - accuracy: 0.6493 - val_loss: 1.8182 - val_accuracy: 0.4635
# Epoch 59/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 0.9211 - accuracy: 0.7101 - val_loss: 1.8962 - val_accuracy: 0.4740
# Epoch 60/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 0.7633 - accuracy: 0.7378 - val_loss: 1.8088 - val_accuracy: 0.5286
# Epoch 61/100
# 9/9 [==============================] - ETA: 0s - batch: 4.0000 - size: 128.0000 - loss: 1.0557 - accuracy: 0.6780INFO:tensorflow:Assets written to: model1\assets
# 9/9 [==============================] - 31s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 1.0557 - accuracy: 0.6780 - val_loss: 1.4583 - val_accuracy: 0.5495
# Epoch 62/100
# 9/9 [==============================] - 24s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 0.6612 - accuracy: 0.7969 - val_loss: 1.5379 - val_accuracy: 0.5625
# Epoch 63/100
# 9/9 [==============================] - 28s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 0.6363 - accuracy: 0.8064 - val_loss: 1.5681 - val_accuracy: 0.5417
# Epoch 64/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 1.7111 - accuracy: 0.5868 - val_loss: 1.7234 - val_accuracy: 0.5026
# Epoch 65/100
# 9/9 [==============================] - 28s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 0.5906 - accuracy: 0.8186 - val_loss: 1.7079 - val_accuracy: 0.5078
# Epoch 66/100
# 9/9 [==============================] - ETA: 0s - batch: 4.0000 - size: 128.0000 - loss: 0.9034 - accuracy: 0.7613INFO:tensorflow:Assets written to: model1\assets
# 9/9 [==============================] - 31s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.9034 - accuracy: 0.7613 - val_loss: 1.3843 - val_accuracy: 0.5417
# Epoch 67/100
# 9/9 [==============================] - 24s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 0.8173 - accuracy: 0.7873 - val_loss: 1.7175 - val_accuracy: 0.4062
# Epoch 68/100
# 9/9 [==============================] - 28s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 0.5438 - accuracy: 0.8307 - val_loss: 1.3988 - val_accuracy: 0.5833
# Epoch 69/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 0.5575 - accuracy: 0.8464 - val_loss: 1.7585 - val_accuracy: 0.4167
# Epoch 70/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 1.4653 - accuracy: 0.6250 - val_loss: 1.6885 - val_accuracy: 0.5547
# Epoch 71/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 0.4740 - accuracy: 0.8628 - val_loss: 1.7892 - val_accuracy: 0.5130
# Epoch 72/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 0.4403 - accuracy: 0.8559 - val_loss: 1.9476 - val_accuracy: 0.5729
# Epoch 73/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 0.4122 - accuracy: 0.9097 - val_loss: 3.1445 - val_accuracy: 0.3464
# Epoch 74/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 0.9069 - accuracy: 0.7326 - val_loss: 1.7958 - val_accuracy: 0.4896
# Epoch 75/100
# 9/9 [==============================] - ETA: 0s - batch: 4.0000 - size: 128.0000 - loss: 0.5116 - accuracy: 0.8594INFO:tensorflow:Assets written to: model1\assets
# 9/9 [==============================] - 31s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.5116 - accuracy: 0.8594 - val_loss: 1.3151 - val_accuracy: 0.6094
# Epoch 76/100
# 9/9 [==============================] - 24s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 0.5880 - accuracy: 0.8316 - val_loss: 1.5089 - val_accuracy: 0.6302
# Epoch 77/100
# 9/9 [==============================] - 28s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 0.6855 - accuracy: 0.8559 - val_loss: 1.5558 - val_accuracy: 0.5469
# Epoch 78/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 0.8682 - accuracy: 0.7734 - val_loss: 2.1155 - val_accuracy: 0.4661
# Epoch 79/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 0.3977 - accuracy: 0.8984 - val_loss: 2.3649 - val_accuracy: 0.4844
# Epoch 80/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 0.3470 - accuracy: 0.9097 - val_loss: 1.8882 - val_accuracy: 0.4974
# Epoch 81/100
# 9/9 [==============================] - 28s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 0.2880 - accuracy: 0.9332 - val_loss: 2.7979 - val_accuracy: 0.4375
# Epoch 82/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 0.8035 - accuracy: 0.8064 - val_loss: 1.5687 - val_accuracy: 0.6276
# Epoch 83/100
# 9/9 [==============================] - 28s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 0.2705 - accuracy: 0.9366 - val_loss: 1.7365 - val_accuracy: 0.5990
# Epoch 84/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 0.3880 - accuracy: 0.9141 - val_loss: 2.6324 - val_accuracy: 0.4818
# Epoch 85/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 0.5992 - accuracy: 0.8655 - val_loss: 1.7154 - val_accuracy: 0.4688
# Epoch 86/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 0.2680 - accuracy: 0.9384 - val_loss: 2.1332 - val_accuracy: 0.5755
# Epoch 87/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 0.3971 - accuracy: 0.9002 - val_loss: 1.9189 - val_accuracy: 0.4271
# Epoch 88/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 1.2932 - accuracy: 0.7040 - val_loss: 1.4464 - val_accuracy: 0.5807
# Epoch 89/100
# 9/9 [==============================] - 28s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 0.2514 - accuracy: 0.9583 - val_loss: 1.8666 - val_accuracy: 0.5599
# Epoch 90/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 0.2044 - accuracy: 0.9497 - val_loss: 2.1614 - val_accuracy: 0.5964
# Epoch 91/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 0.3991 - accuracy: 0.9323 - val_loss: 1.6022 - val_accuracy: 0.5182
# Epoch 92/100
# 9/9 [==============================] - 28s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 1.2385 - accuracy: 0.7240 - val_loss: 1.6443 - val_accuracy: 0.5625
# Epoch 93/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 0.3228 - accuracy: 0.9306 - val_loss: 2.1543 - val_accuracy: 0.5547
# Epoch 94/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 0.1593 - accuracy: 0.9618 - val_loss: 2.3468 - val_accuracy: 0.5964
# Epoch 95/100
# 9/9 [==============================] - 28s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 0.3531 - accuracy: 0.9262 - val_loss: 1.9068 - val_accuracy: 0.5964
# CPU times: total: 1h 27min 18s
# Wall time: 43min 23s

# %%
history1.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# let's plot the loss and accuracy 

# get the training and validation accuracy from the history object
train_acc = history1.history['accuracy']
valid_acc = history1.history['val_accuracy']

# get the loss
train_loss = history1.history['loss']
valid_loss = history1.history['val_loss']

# get the number of entries
xvalues = np.arange(len(train_acc))

# visualize
f,ax = plt.subplots(1,2, figsize=(10,5))
ax[0].plot(xvalues, train_loss)
ax[0].plot(xvalues, valid_loss)
ax[0].set_title("Loss curve")
ax[0].set_xlabel("Epoch")
ax[0].set_ylabel("loss")
ax[0].legend(['train', 'validation'])

ax[1].plot(xvalues, train_acc)
ax[1].plot(xvalues, valid_acc)
ax[1].set_title("Accuracy")
ax[1].set_xlabel("Epoch")
ax[1].set_ylabel("accuracy")
ax[1].legend(['train', 'validation'])

plt.show()

# %%
# What is the final loss and accuracy on our validation data?
valid_loss, valid_acc = model.evaluate_generator(valid_data_gen, steps=num_valid_steps)
print(f"Final validation accuracy: {valid_acc*100:.2f}%")
# Out:
# C:\Users\danie\anaconda3\envs\tf\lib\site-packages\keras\engine\training_v1.py:1261: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\envs\tf\lib\site-packages\keras\utils\data_utils.py:888, in GeneratorEnqueuer.get(self)
#     887 while self.is_running():
# --> 888   inputs = self.queue.get(block=True).get()
#     889   self.queue.task_done()
#
# File ~\anaconda3\envs\tf\lib\multiprocessing\pool.py:768, in ApplyResult.get(self, timeout)
#     767 else:
# --> 768     raise self._value
#
# File ~\anaconda3\envs\tf\lib\multiprocessing\pool.py:125, in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     124 try:
# --> 125     result = (True, func(*args, **kwds))
#     126 except Exception as e:
#
# File ~\anaconda3\envs\tf\lib\site-packages\keras\utils\data_utils.py:825, in next_sample(uid)
#     813 """Gets the next value from the generator `uid`.
#     814
#     815 To allow multiple generators to be used at the same time, we use `uid` to
#    (...)
#     823     The next value of generator `uid`.
#     824 """
# --> 825 return next(_SHARED_SEQUENCES[uid])
#
# ValueError: generator already executing
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[25], line 2
#       1 # What is the final loss and accuracy on our validation data?
# ----> 2 valid_loss, valid_acc = model.evaluate_generator(valid_data_gen, steps=num_valid_steps)
#       3 print(f"Final validation accuracy: {valid_acc*100:.2f}%")
#
# File ~\anaconda3\envs\tf\lib\site-packages\keras\engine\training_v1.py:1266, in Model.evaluate_generator(self, generator, steps, callbacks, max_queue_size, workers, use_multiprocessing, verbose)
#    1261 warnings.warn('`Model.evaluate_generator` is deprecated and '
#    1262               'will be removed in a future version. '
#    1263               'Please use `Model.evaluate`, which supports generators.')
#    1264 self._check_call_args('evaluate_generator')
# -> 1266 return self.evaluate(
#    1267     generator,
#    1268     steps=steps,
#    1269     max_queue_size=max_queue_size,
#    1270     workers=workers,
#    1271     use_multiprocessing=use_multiprocessing,
#    1272     verbose=verbose,
#    1273     callbacks=callbacks)
#
# File ~\anaconda3\envs\tf\lib\site-packages\keras\engine\training_v1.py:891, in Model.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#     888 self._check_call_args('evaluate')
#     890 func = self._select_training_loop(x)
# --> 891 return func.evaluate(
#     892     self,
#     893     x=x,
#     894     y=y,
#     895     batch_size=batch_size,
#     896     verbose=verbose,
#     897     sample_weight=sample_weight,
#     898     steps=steps,
#     899     callbacks=callbacks,
#     900     max_queue_size=max_queue_size,
#     901     workers=workers,
#     902     use_multiprocessing=use_multiprocessing)
#
# File ~\anaconda3\envs\tf\lib\site-packages\keras\engine\training_generator_v1.py:602, in GeneratorOrSequenceTrainingLoop.evaluate(self, model, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#     600 model._validate_or_infer_batch_size(batch_size, steps, x)
#     601 training_utils_v1.check_generator_arguments(y, sample_weight)
# --> 602 return evaluate_generator(
#     603     model,
#     604     x,
#     605     steps=steps,
#     606     verbose=verbose,
#     607     callbacks=callbacks,
#     608     max_queue_size=max_queue_size,
#     609     workers=workers,
#     610     use_multiprocessing=use_multiprocessing)
#
# File ~\anaconda3\envs\tf\lib\site-packages\keras\engine\training_generator_v1.py:212, in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, steps_name, **kwargs)
#     210 step = 0
#     211 while step < target_steps:
# --> 212   batch_data = _get_next_batch(generator)
#     213   if batch_data is None:
#     214     if is_dataset:
#     215       # The dataset passed by the user ran out of batches.
#     216       # Now we know the cardinality of the dataset.
#     217       # If steps_per_epoch was specified, then running out of data is
#     218       # unexpected, so we stop training and inform the user.
#
# File ~\anaconda3\envs\tf\lib\site-packages\keras\engine\training_generator_v1.py:346, in _get_next_batch(generator)
#     344 """Retrieves the next batch of input data."""
#     345 try:
# --> 346   generator_output = next(generator)
#     347 except (StopIteration, tf.errors.OutOfRangeError):
#     348   return None
#
# File ~\anaconda3\envs\tf\lib\site-packages\keras\utils\data_utils.py:908, in GeneratorEnqueuer.get(self)
#     906 self.stop()
#     907 if 'generator already executing' in str(e):
# --> 908   raise RuntimeError(
#     909       'Your generator is NOT thread-safe. '
#     910       'Keras requires a thread-safe generator when '
#     911       '`use_multiprocessing=False, workers > 1`. ')
#     912 raise e
#
# RuntimeError: Your generator is NOT thread-safe. Keras requires a thread-safe generator when `use_multiprocessing=False, workers > 1`.

# %%
outputs = [layer.output for layer in model.layers[1:18]]

vis_model = Model(model.input, outputs)

for layer in vis_model.layers:
  layer.trainable = False

vis_model.summary()

# %%
# store the layer names we are interested in
layer_names = []
for layer in outputs:
    layer_names.append(layer.name.split("/")[0])

    
print("Layers going to be used for visualization: ")
print(layer_names)

# %%
print( f'layer_names [before]: {layer_names}' )

layer_names_temp = layer_names
layer_names = list()
for layer in layer_names_temp:

  if 'conv' in layer:
    # print(layer)
    layer_names.append( layer )

print( '=========================================' )
print( f'layer_names [after]: {layer_names}' )

# %%
def get_CAM(processed_image, predicted_label):
    """
    This function is used to generate a heatmap for a sample image prediction.
    
    Args:
        processed_image: any sample image that has been pre-processed using the 
                       `preprocess_input()`method of a keras model
        predicted_label: label that has been predicted by the network for this image
    
    Returns:
        heatmap: heatmap generated over the last convolution layer output 
    """
    # we want the activations for the predicted label
    predicted_output = model.output[:, predicted_label]
    
    # choose the last conv layer in your model
    # last_conv_layer = model.get_layer('block5_conv3')
    last_conv_layer = model.get_layer(layer_names[-1])
    
    # get the gradients wrt to the last conv layer
    grads = K.gradients(predicted_output, last_conv_layer.output)[0]
    
    # take mean gradient per feature map
    grads = K.mean(grads, axis=(0,1,2)) # GAP - Global Average Pooling
    
    # Define a function that generates the values for the output and gradients
    evaluation_function = K.function([model.input], [grads, last_conv_layer.output[0]])
    
    # get the values
    grads_values, conv_ouput_values = evaluation_function([processed_image])
    
    # CAM - Class Activation Map
    # iterate over each feature map in yout conv output and multiply
    # the gradient values with the conv output values. This gives an 
    # indication of "how important a feature is"
    # for i in range(512): # we have 512 features in our last conv layer
    for i in range(conv_ouput_values.shape[2]): # daniel
        conv_ouput_values[:,:,i] *= grads_values[i]
    
    # create a heatmap
    heatmap = np.mean(conv_ouput_values, axis=-1)
    
    # remove negative values
    heatmap = np.maximum(heatmap, 0)
    
    # normalize
    heatmap /= heatmap.max()
    
    return heatmap

# %%
idx = 0

# %%
# select the sample and read the corresponding image and label
sample_image = cv2.imread(valid_df.iloc[idx]['image'])
sample_image = cv2.cvtColor(sample_image, cv2.COLOR_BGR2RGB)
sample_image = cv2.resize(sample_image, (img_rows, img_cols))
sample_label = valid_df.iloc[idx]["label"]

# pre-process the image
sample_image_processed = np.expand_dims(sample_image, axis=0)
sample_image_processed = preprocess_input(sample_image_processed)

# get the label predicted by our original model
pred_label = np.argmax(model.predict(sample_image_processed), axis=-1)[0]

# get the heatmap for class activation map(CAM)
heatmap = get_CAM(sample_image_processed, pred_label)
heatmap = cv2.resize(heatmap, (sample_image.shape[0], sample_image.shape[1]))
heatmap = heatmap *255
heatmap = np.clip(heatmap, 0, 255).astype(np.uint8)
heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
super_imposed_image = heatmap * 0.5 + sample_image
super_imposed_image = np.clip(super_imposed_image, 0,255).astype(np.uint8)

# Ploting
fontsize = 10
fig, axes = plt.subplots( 1, 3, figsize=( 8, 8 ) )
axes[0].set_title( f'True label: {sample_label} \n Predicted label: {pred_label}',
                  fontsize = fontsize )
axes[0].axis('off')
axes[0].imshow( sample_image )

axes[1].set_title( f'Class Activation Map',
                  fontsize = fontsize )
axes[1].axis('off')
axes[1].imshow( heatmap )

axes[2].set_title( f'Activation Map Superimposed',
                  fontsize = fontsize )
axes[2].axis('off')
axes[2].imshow( super_imposed_image )
plt.show()

# # Plot just CAM of the layer
# plt.figure( figsize=(2, 2) )
# plt.title( f'Class Activation Map - Layer: {layer}' )
# plt.imshow( heatmap )
# plt.show()
