# %%
# from google.colab import drive
# drive.mount('/content/drive', force_remount=True)

# %%
# cd "drive/MyDrive/Doutorado/Disciplinas/[2022.2] [PUC-Rio] Visão Computacional - Professor: Marcelo Gattass/Trabalhos/Trabalho Final/Code/What does a CNN see?/"

# %%
# !pwd

# %%
data_folder = './data/'

# %% [markdown]
# # Imports

# %%
import os
import cv2
import glob
import imgaug as aug
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import imgaug.augmenters as iaa
from os import listdir
from pathlib import Path
from keras.models import Sequential, Model
# from keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from keras.callbacks import ModelCheckpoint, EarlyStopping
# from keras.utils import to_categorical
from tensorflow.keras.utils import to_categorical
from keras import backend as K
from keras.applications.vgg16 import preprocess_input
import tensorflow as tf
tf.compat.v1.disable_eager_execution()


color = sns.color_palette()
# %matplotlib inline
# %config InlineBackend.figure_format="svg"

# Daniel
from tensorflow.keras import layers, models

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
print(tf.__version__)
# Out:
# 2.6.0

# %% [markdown]
# # Seed

# %%
# Set the seed for hash based operations in python
os.environ['PYTHONHASHSEED'] = '0'

seed=1234

# Set the numpy seed
np.random.seed(seed)

# Set the random seed in tensorflow at graph level
# tf.set_random_seed(seed) # obsolete
tf.random.set_seed(seed)

# Make the augmentation sequence deterministic
aug.seed(seed)

# %%
# As usual, define some paths first to make life simpler
training_data = Path(data_folder + '/training/') 
validation_data = Path(data_folder + '/validation/') 
labels_path = Path(data_folder + '/monkey_labels.txt')

# %%
labels_info = []

# Read the file
lines = labels_path.read_text().strip().splitlines()[1:]
for line in lines:
    line = line.split(',')
    line = [x.strip(' \n\t\r') for x in line]
    line[3], line[4] = int(line[3]), int(line[4])
    line = tuple(line)
    labels_info.append(line)
    
# Convert the data into a pandas dataframe
labels_info = pd.DataFrame(labels_info, columns=['Label', 'Latin Name', 'Common Name', 
                                                 'Train Images', 'Validation Images'], index=None)
# Sneak peek 
labels_info.head(10)
# Out:
#   Label             Latin Name                Common Name  Train Images  \
# 0    n0      alouatta_palliata             mantled_howler           131
# 1    n1     erythrocebus_patas               patas_monkey           139
# 2    n2         cacajao_calvus                bald_uakari           137
# 3    n3         macaca_fuscata           japanese_macaque           152
# 4    n4        cebuella_pygmea             pygmy_marmoset           131
# 5    n5        cebus_capucinus      white_headed_capuchin           141
# 6    n6        mico_argentatus           silvery_marmoset           132
# 7    n7       saimiri_sciureus     common_squirrel_monkey           142
# 8    n8        aotus_nigriceps  black_headed_night_monkey           133
# 9    n9  trachypithecus_johnii             nilgiri_langur           132
#
#    Validation Images
# 0                 26
# 1                 28
# 2                 27
# 3                 30
# 4                 26
# 5                 28
# 6                 26
# 7                 28
# 8                 27
# 9                 26

# %%
# Create a dictionary to map the labels to integers
labels_dict= {'n0':0, 'n1':1, 'n2':2, 'n3':3, 'n4':4, 'n5':5, 'n6':6, 'n7':7, 'n8':8, 'n9':9}

# map labels to common names
names_dict = dict(zip(labels_dict.values(), labels_info["Common Name"]))
print(names_dict)
# Out:
# {0: 'mantled_howler', 1: 'patas_monkey', 2: 'bald_uakari', 3: 'japanese_macaque', 4: 'pygmy_marmoset', 5: 'white_headed_capuchin', 6: 'silvery_marmoset', 7: 'common_squirrel_monkey', 8: 'black_headed_night_monkey', 9: 'nilgiri_langur'}

# %%
# Creating a dataframe for the training dataset
train_df = []
for folder in os.listdir(training_data):
    # Define the path to the images
    imgs_path = training_data / folder
    
    # Get the list of all the images stored in that directory
    imgs = sorted(imgs_path.glob('*.jpg'))
    
    # Store each image path and corresponding label 
    for img_name in imgs:
        train_df.append((str(img_name), labels_dict[folder]))


train_df = pd.DataFrame(train_df, columns=['image', 'label'], index=None)
# shuffle the dataset 
train_df = train_df.sample(frac=1.).reset_index(drop=True)

####################################################################################################

# Creating dataframe for validation data in a similar fashion
valid_df = []
for folder in os.listdir(validation_data):
    imgs_path = validation_data / folder
    imgs = sorted(imgs_path.glob('*.jpg'))
    for img_name in imgs:
        valid_df.append((str(img_name), labels_dict[folder]))

        
valid_df = pd.DataFrame(valid_df, columns=['image', 'label'], index=None)
# shuffle the dataset 
valid_df = valid_df.sample(frac=1.).reset_index(drop=True)

####################################################################################################

# How many samples do we have in our training and validation data?
print("Number of traininng samples: ", len(train_df))
print("Number of validation samples: ", len(valid_df))

# sneak peek of the training and validation dataframes
print("\n",train_df.head(), "\n")
print("=================================================================\n")
print("\n", valid_df.head())
# Out:
# Number of traininng samples:  1097
# Number of validation samples:  272
#
#                          image  label
# 0  data\training\n0\n0134.jpg      0
# 1  data\training\n4\n4114.jpg      4
# 2  data\training\n4\n4059.jpg      4
# 3  data\training\n3\n3061.jpg      3
# 4  data\training\n0\n0150.jpg      0
#
# =================================================================
#
#
#                            image  label
# 0   data\validation\n2\n218.jpg      2
# 1  data\validation\n3\n3013.jpg      3
# 2  data\validation\n2\n2011.jpg      2
# 3   data\validation\n6\n608.jpg      6
# 4   data\validation\n6\n605.jpg      6

# %% [markdown]
# # batch_size

# %%
batch_size=128

# %%
# some constants(not truly though!) 

# dimensions to consider for the images
img_rows, img_cols, img_channels = 224,224,3

# total number of classes in the dataset
nb_classes=10

# %%
# Augmentation sequence 
seq = iaa.OneOf([
    iaa.Fliplr(), # horizontal flips
    iaa.Affine(rotate=20), # roatation
    iaa.Multiply((1.2, 1.5))]) #random brightness

# %%
def data_generator(data, batch_size, is_validation_data=False):
    # Get total number of samples in the data
    n = len(data)
    nb_batches = int(np.ceil(n/batch_size))

    # Get a numpy array of all the indices of the input data
    indices = np.arange(n)
    
    # Define two numpy arrays for containing batch data and labels
    batch_data = np.zeros((batch_size, img_rows, img_cols, img_channels), dtype=np.float32)
    batch_labels = np.zeros((batch_size, nb_classes), dtype=np.float32)
    
    while True:
        if not is_validation_data:
            # shuffle indices for the training data
            np.random.shuffle(indices)
            
        for i in range(nb_batches):
            # get the next batch 
            next_batch_indices = indices[i*batch_size:(i+1)*batch_size]
            
            # process the next batch
            for j, idx in enumerate(next_batch_indices):
                img = cv2.imread(data.iloc[idx]["image"])
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                label = data.iloc[idx]["label"]
                
                if not is_validation_data:
                    img = seq.augment_image(img)
                
                img = cv2.resize(img, (img_rows, img_cols)).astype(np.float32)
                batch_data[j] = img
                batch_labels[j] = to_categorical(label,num_classes=nb_classes)
            
            batch_data = preprocess_input(batch_data)
            yield batch_data, batch_labels

# %%
#training data generator 
train_data_gen = data_generator(train_df, batch_size)

# validation data generator 
valid_data_gen = data_generator(valid_df, batch_size, is_validation_data=True)

# %% [markdown]
# # kernel_size

# %%
kernel_size = 2

# %% [markdown]
# # Net Architecture

# %%
# https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D
# tf.keras.layers.Conv2D( filters, kernel_size, ...)

model = models.Sequential([
    layers.InputLayer( input_shape=(224, 224, 3) )
])

### 1 conv layer
model.add( layers.Conv2D(16, (kernel_size, kernel_size), 
                        padding='same',
                        activation='relu') )
model.add( layers.MaxPooling2D((2, 2)) )

### 2 conv layer
model.add( layers.Conv2D(32, (kernel_size, kernel_size), 
                        padding='same',
                        activation='relu') )
model.add( layers.MaxPooling2D((2, 2)) )

### 3 conv layer
model.add( layers.Conv2D(64, (kernel_size, kernel_size), 
                        padding='same',
                        activation='relu') )
model.add( layers.MaxPooling2D((2, 2)) )

### 4 conv layer
model.add( layers.Conv2D(128, (kernel_size, kernel_size), 
                        padding='same',
                        activation='relu') )
model.add( layers.MaxPooling2D((2, 2)) )

### 5 conv layer
model.add( layers.Conv2D(256, (kernel_size, kernel_size), 
                        padding='same',
                        activation='relu') )
model.add( layers.MaxPooling2D((2, 2)) )

### 6 fully layers
model.add( layers.Flatten() )
model.add( layers.Dense(4096, activation='relu') )
model.add( layers.Dense(4096, activation='relu') )
model.add( layers.Dropout(0.2) )
model.add( layers.Dense(10, activation='softmax') )

# To correct some bug on input
model = Model(model.input, model.output)

optimizer = RMSprop(0.001)
model.compile(optimizer = optimizer, 
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 224, 224, 16)      208
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 32)      2080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 56, 56, 64)        8256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 128)       32896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 14, 14, 256)       131328
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 12544)             0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              51384320
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                40970
# =================================================================
# Total params: 68,381,370
# Trainable params: 68,381,370
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stopping = EarlyStopping(patience=20, restore_best_weights=True)

model_checkpoint = ModelCheckpoint(filepath="model1", save_best_only=True)

num_train_steps = int(np.ceil(len(train_df)/batch_size))
num_valid_steps = int(np.ceil(len(valid_df)/batch_size))

# %%
epochs=100
# epochs=5 # daniel

# %% [markdown]
# # Training

# %%
# %%time

history1 = model.fit(train_data_gen, 
                              epochs = epochs, 
                              steps_per_epoch = num_train_steps, 
                              validation_data = valid_data_gen, 
                              validation_steps = num_valid_steps,
                              callbacks = [early_stopping, model_checkpoint])
# Out:
# Epoch 1/100
# 9/9 [==============================] - ETA: 0s - batch: 4.0000 - size: 128.0000 - loss: 730.3010 - accuracy: 0.0955
# C:\Users\danie\anaconda3\envs\tf\lib\site-packages\keras\engine\training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# INFO:tensorflow:Assets written to: model1\assets
# 9/9 [==============================] - 37s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 730.3010 - accuracy: 0.0955 - val_loss: 3.1288 - val_accuracy: 0.1302
# Epoch 2/100
# 9/9 [==============================] - ETA: 0s - batch: 4.0000 - size: 128.0000 - loss: 2.5143 - accuracy: 0.1667INFO:tensorflow:Assets written to: model1\assets
# 9/9 [==============================] - 28s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 2.5143 - accuracy: 0.1667 - val_loss: 2.2133 - val_accuracy: 0.1979
# Epoch 3/100
# 9/9 [==============================] - 24s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 2.2322 - accuracy: 0.1988 - val_loss: 2.2164 - val_accuracy: 0.1927
# Epoch 4/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 2.2594 - accuracy: 0.2222 - val_loss: 2.2550 - val_accuracy: 0.1016
# Epoch 5/100
# 9/9 [==============================] - ETA: 0s - batch: 4.0000 - size: 128.0000 - loss: 2.2918 - accuracy: 0.1788INFO:tensorflow:Assets written to: model1\assets
# 9/9 [==============================] - 32s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 2.2918 - accuracy: 0.1788 - val_loss: 2.2112 - val_accuracy: 0.2526
# Epoch 6/100
# 9/9 [==============================] - 25s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 4.2853 - accuracy: 0.1997 - val_loss: 2.2895 - val_accuracy: 0.1641
# Epoch 7/100
# 9/9 [==============================] - ETA: 0s - batch: 4.0000 - size: 128.0000 - loss: 2.2593 - accuracy: 0.2153INFO:tensorflow:Assets written to: model1\assets
# 9/9 [==============================] - 31s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 2.2593 - accuracy: 0.2153 - val_loss: 2.2105 - val_accuracy: 0.1953
# Epoch 8/100
# 9/9 [==============================] - 25s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 2.3982 - accuracy: 0.2639 - val_loss: 2.3480 - val_accuracy: 0.2344
# Epoch 9/100
# 9/9 [==============================] - ETA: 0s - batch: 4.0000 - size: 128.0000 - loss: 2.1149 - accuracy: 0.2821INFO:tensorflow:Assets written to: model1\assets
# 9/9 [==============================] - 32s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 2.1149 - accuracy: 0.2821 - val_loss: 2.1722 - val_accuracy: 0.2865
# Epoch 10/100
# 9/9 [==============================] - 25s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 4.7983 - accuracy: 0.2101 - val_loss: 4.1080 - val_accuracy: 0.1432
# Epoch 11/100
# 9/9 [==============================] - 28s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 3.2853 - accuracy: 0.2283 - val_loss: 2.6884 - val_accuracy: 0.1953
# Epoch 12/100
# 9/9 [==============================] - 28s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 2.1183 - accuracy: 0.2951 - val_loss: 2.2216 - val_accuracy: 0.2083
# Epoch 13/100
# 9/9 [==============================] - ETA: 0s - batch: 4.0000 - size: 128.0000 - loss: 2.0707 - accuracy: 0.2535INFO:tensorflow:Assets written to: model1\assets
# 9/9 [==============================] - 31s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 2.0707 - accuracy: 0.2535 - val_loss: 2.1412 - val_accuracy: 0.2578
# Epoch 14/100
# 9/9 [==============================] - 24s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 2.9528 - accuracy: 0.2917 - val_loss: 2.4879 - val_accuracy: 0.1823
# Epoch 15/100
# 9/9 [==============================] - 28s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 2.1333 - accuracy: 0.2925 - val_loss: 2.2686 - val_accuracy: 0.1823
# Epoch 16/100
# 9/9 [==============================] - ETA: 0s - batch: 4.0000 - size: 128.0000 - loss: 2.1935 - accuracy: 0.2986INFO:tensorflow:Assets written to: model1\assets
# 9/9 [==============================] - 31s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 2.1935 - accuracy: 0.2986 - val_loss: 2.1209 - val_accuracy: 0.3099
# Epoch 17/100
# 9/9 [==============================] - ETA: 0s - batch: 4.0000 - size: 128.0000 - loss: 2.9945 - accuracy: 0.2474INFO:tensorflow:Assets written to: model1\assets
# 9/9 [==============================] - 28s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 2.9945 - accuracy: 0.2474 - val_loss: 1.9577 - val_accuracy: 0.3229
# Epoch 18/100
# 9/9 [==============================] - 25s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 2.5406 - accuracy: 0.3273 - val_loss: 2.5348 - val_accuracy: 0.1849
# Epoch 19/100
# 9/9 [==============================] - ETA: 0s - batch: 4.0000 - size: 128.0000 - loss: 1.8350 - accuracy: 0.3594INFO:tensorflow:Assets written to: model1\assets
# 9/9 [==============================] - 30s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 1.8350 - accuracy: 0.3594 - val_loss: 1.8025 - val_accuracy: 0.3802
# Epoch 20/100
# 9/9 [==============================] - 24s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 1.7660 - accuracy: 0.4028 - val_loss: 1.8485 - val_accuracy: 0.3490
# Epoch 21/100
# 9/9 [==============================] - 28s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 1.8323 - accuracy: 0.3759 - val_loss: 1.8367 - val_accuracy: 0.3229
# Epoch 22/100
# 9/9 [==============================] - 28s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 2.1342 - accuracy: 0.3290 - val_loss: 2.0061 - val_accuracy: 0.2969
# Epoch 23/100
# 9/9 [==============================] - 29s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 1.9918 - accuracy: 0.3620 - val_loss: 2.1865 - val_accuracy: 0.2995
# Epoch 24/100
# 9/9 [==============================] - 29s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 1.6592 - accuracy: 0.4245 - val_loss: 2.1019 - val_accuracy: 0.3385
# Epoch 25/100
# 9/9 [==============================] - ETA: 0s - batch: 4.0000 - size: 128.0000 - loss: 1.7199 - accuracy: 0.4219INFO:tensorflow:Assets written to: model1\assets
# 9/9 [==============================] - 32s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 1.7199 - accuracy: 0.4219 - val_loss: 1.5842 - val_accuracy: 0.4844
# Epoch 26/100
# 9/9 [==============================] - 26s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 1.6486 - accuracy: 0.4688 - val_loss: 2.3024 - val_accuracy: 0.3568
# Epoch 27/100
# 9/9 [==============================] - 30s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 1.6065 - accuracy: 0.4870 - val_loss: 1.7447 - val_accuracy: 0.3672
# Epoch 28/100
# 9/9 [==============================] - 29s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 1.4847 - accuracy: 0.5252 - val_loss: 2.4179 - val_accuracy: 0.2214
# Epoch 29/100
# 9/9 [==============================] - 30s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 1.6162 - accuracy: 0.4818 - val_loss: 1.7826 - val_accuracy: 0.4323
# Epoch 30/100
# 9/9 [==============================] - ETA: 0s - batch: 4.0000 - size: 128.0000 - loss: 1.5882 - accuracy: 0.4783INFO:tensorflow:Assets written to: model1\assets
# 9/9 [==============================] - 33s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 1.5882 - accuracy: 0.4783 - val_loss: 1.5796 - val_accuracy: 0.4766
# Epoch 31/100
# 9/9 [==============================] - ETA: 0s - batch: 4.0000 - size: 128.0000 - loss: 1.0608 - accuracy: 0.6484INFO:tensorflow:Assets written to: model1\assets
# 9/9 [==============================] - 32s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 1.0608 - accuracy: 0.6484 - val_loss: 1.5609 - val_accuracy: 0.4922
# Epoch 32/100
# 9/9 [==============================] - ETA: 0s - batch: 4.0000 - size: 128.0000 - loss: 2.1863 - accuracy: 0.4766INFO:tensorflow:Assets written to: model1\assets
# 9/9 [==============================] - 30s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 2.1863 - accuracy: 0.4766 - val_loss: 1.4203 - val_accuracy: 0.4766
# Epoch 33/100
# 9/9 [==============================] - 26s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 1.2561 - accuracy: 0.5877 - val_loss: 1.5089 - val_accuracy: 0.4922
# Epoch 34/100
# 9/9 [==============================] - 29s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 1.0232 - accuracy: 0.6693 - val_loss: 1.5509 - val_accuracy: 0.4609
# Epoch 35/100
# 9/9 [==============================] - 30s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.8838 - accuracy: 0.7405 - val_loss: 1.4396 - val_accuracy: 0.5495
# Epoch 36/100
# 9/9 [==============================] - 30s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.7602 - accuracy: 0.7700 - val_loss: 1.8442 - val_accuracy: 0.4323
# Epoch 37/100
# 9/9 [==============================] - ETA: 0s - batch: 4.0000 - size: 128.0000 - loss: 0.9420 - accuracy: 0.7014INFO:tensorflow:Assets written to: model1\assets
# 9/9 [==============================] - 37s 5s/step - batch: 4.0000 - size: 128.0000 - loss: 0.9420 - accuracy: 0.7014 - val_loss: 1.3112 - val_accuracy: 0.5625
# Epoch 38/100
# 9/9 [==============================] - 23s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 1.6566 - accuracy: 0.5373 - val_loss: 1.4891 - val_accuracy: 0.5391
# Epoch 39/100
# 9/9 [==============================] - 29s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.9222 - accuracy: 0.7014 - val_loss: 1.4288 - val_accuracy: 0.5286
# Epoch 40/100
# 9/9 [==============================] - 29s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.6027 - accuracy: 0.8073 - val_loss: 1.7207 - val_accuracy: 0.5260
# Epoch 41/100
# 9/9 [==============================] - 30s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.7934 - accuracy: 0.7717 - val_loss: 1.5070 - val_accuracy: 0.5286
# Epoch 42/100
# 9/9 [==============================] - 30s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.7994 - accuracy: 0.7604 - val_loss: 1.7080 - val_accuracy: 0.4974
# Epoch 43/100
# 9/9 [==============================] - 30s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.6702 - accuracy: 0.8003 - val_loss: 1.5752 - val_accuracy: 0.5182
# Epoch 44/100
# 9/9 [==============================] - 30s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 1.3594 - accuracy: 0.6510 - val_loss: 1.6407 - val_accuracy: 0.5078
# Epoch 45/100
# 9/9 [==============================] - 30s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.4628 - accuracy: 0.8759 - val_loss: 2.1808 - val_accuracy: 0.4557
# Epoch 46/100
# 9/9 [==============================] - 29s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.6017 - accuracy: 0.8299 - val_loss: 1.8360 - val_accuracy: 0.5104
# Epoch 47/100
# 9/9 [==============================] - 30s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.7719 - accuracy: 0.7778 - val_loss: 1.4447 - val_accuracy: 0.5781
# Epoch 48/100
# 9/9 [==============================] - 30s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.4801 - accuracy: 0.8550 - val_loss: 1.3558 - val_accuracy: 0.5495
# Epoch 49/100
# 9/9 [==============================] - 31s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.4669 - accuracy: 0.8819 - val_loss: 1.9086 - val_accuracy: 0.5469
# Epoch 50/100
# 9/9 [==============================] - ETA: 0s - batch: 4.0000 - size: 128.0000 - loss: 1.1133 - accuracy: 0.7179INFO:tensorflow:Assets written to: model1\assets
# 9/9 [==============================] - 34s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 1.1133 - accuracy: 0.7179 - val_loss: 1.3007 - val_accuracy: 0.6224
# Epoch 51/100
# 9/9 [==============================] - 26s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 1.0385 - accuracy: 0.7326 - val_loss: 1.6123 - val_accuracy: 0.5833
# Epoch 52/100
# 9/9 [==============================] - 29s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.3729 - accuracy: 0.8950 - val_loss: 1.8055 - val_accuracy: 0.5260
# Epoch 53/100
# 9/9 [==============================] - 29s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.3767 - accuracy: 0.9106 - val_loss: 1.7894 - val_accuracy: 0.5651
# Epoch 54/100
# 9/9 [==============================] - 29s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.6657 - accuracy: 0.8168 - val_loss: 1.7460 - val_accuracy: 0.5547
# Epoch 55/100
# 9/9 [==============================] - 29s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.5819 - accuracy: 0.8924 - val_loss: 1.6299 - val_accuracy: 0.5208
# Epoch 56/100
# 9/9 [==============================] - 29s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 1.0609 - accuracy: 0.7109 - val_loss: 1.4063 - val_accuracy: 0.6328
# Epoch 57/100
# 9/9 [==============================] - 29s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.3193 - accuracy: 0.9262 - val_loss: 1.9314 - val_accuracy: 0.5391
# Epoch 58/100
# 9/9 [==============================] - 29s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.3971 - accuracy: 0.9002 - val_loss: 1.8648 - val_accuracy: 0.4479
# Epoch 59/100
# 9/9 [==============================] - 30s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.3540 - accuracy: 0.9097 - val_loss: 1.6895 - val_accuracy: 0.5391
# Epoch 60/100
# 9/9 [==============================] - 29s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.6427 - accuracy: 0.8333 - val_loss: 1.7556 - val_accuracy: 0.5573
# Epoch 61/100
# 9/9 [==============================] - 29s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.3155 - accuracy: 0.9071 - val_loss: 1.8380 - val_accuracy: 0.5755
# Epoch 62/100
# 9/9 [==============================] - 30s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.4641 - accuracy: 0.8872 - val_loss: 1.5893 - val_accuracy: 0.5755
# Epoch 63/100
# 9/9 [==============================] - 29s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.2788 - accuracy: 0.9514 - val_loss: 1.7320 - val_accuracy: 0.5807
# Epoch 64/100
# 9/9 [==============================] - 29s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.6042 - accuracy: 0.8394 - val_loss: 1.4984 - val_accuracy: 0.5703
# Epoch 65/100
# 9/9 [==============================] - 30s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.1539 - accuracy: 0.9566 - val_loss: 1.8666 - val_accuracy: 0.5729
# Epoch 66/100
# 9/9 [==============================] - 29s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.5297 - accuracy: 0.8811 - val_loss: 1.5791 - val_accuracy: 0.5781
# Epoch 67/100
# 9/9 [==============================] - 29s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.5042 - accuracy: 0.8698 - val_loss: 1.5076 - val_accuracy: 0.5703
# Epoch 68/100
# 9/9 [==============================] - ETA: 0s - batch: 4.0000 - size: 128.0000 - loss: 0.3197 - accuracy: 0.9236INFO:tensorflow:Assets written to: model1\assets
# 9/9 [==============================] - 34s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.3197 - accuracy: 0.9236 - val_loss: 1.1964 - val_accuracy: 0.6172
# Epoch 69/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 0.2927 - accuracy: 0.9531 - val_loss: 2.1912 - val_accuracy: 0.5130
# Epoch 70/100
# 9/9 [==============================] - 32s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.5197 - accuracy: 0.8655 - val_loss: 1.5878 - val_accuracy: 0.5677
# Epoch 71/100
# 9/9 [==============================] - 31s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.2928 - accuracy: 0.9384 - val_loss: 1.5449 - val_accuracy: 0.5990
# Epoch 72/100
# 9/9 [==============================] - 31s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.2015 - accuracy: 0.9444 - val_loss: 1.7525 - val_accuracy: 0.5885
# Epoch 73/100
# 9/9 [==============================] - 31s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 1.6715 - accuracy: 0.6745 - val_loss: 1.2156 - val_accuracy: 0.5964
# Epoch 74/100
# 9/9 [==============================] - 30s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.2191 - accuracy: 0.9583 - val_loss: 1.7253 - val_accuracy: 0.6380
# Epoch 75/100
# 9/9 [==============================] - 29s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.2574 - accuracy: 0.9410 - val_loss: 1.7044 - val_accuracy: 0.5859
# Epoch 76/100
# 9/9 [==============================] - 28s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 0.4096 - accuracy: 0.9089 - val_loss: 2.4902 - val_accuracy: 0.5391
# Epoch 77/100
# 9/9 [==============================] - 31s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 1.4508 - accuracy: 0.7934 - val_loss: 1.8212 - val_accuracy: 0.5755
# Epoch 78/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 0.3138 - accuracy: 0.9349 - val_loss: 2.3745 - val_accuracy: 0.5729
# Epoch 79/100
# 9/9 [==============================] - 27s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 0.4109 - accuracy: 0.9010 - val_loss: 1.3108 - val_accuracy: 0.5781
# Epoch 80/100
# 9/9 [==============================] - 29s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.1761 - accuracy: 0.9566 - val_loss: 1.8995 - val_accuracy: 0.6094
# Epoch 81/100
# 9/9 [==============================] - 28s 3s/step - batch: 4.0000 - size: 128.0000 - loss: 0.2747 - accuracy: 0.9444 - val_loss: 3.6321 - val_accuracy: 0.4766
# Epoch 82/100
# 9/9 [==============================] - 28s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.9587 - accuracy: 0.8038 - val_loss: 4.1691 - val_accuracy: 0.5703
# Epoch 83/100
# 9/9 [==============================] - 29s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.5219 - accuracy: 0.8880 - val_loss: 1.7322 - val_accuracy: 0.6354
# Epoch 84/100
# 9/9 [==============================] - 29s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.1660 - accuracy: 0.9635 - val_loss: 2.3153 - val_accuracy: 0.5599
# Epoch 85/100
# 9/9 [==============================] - 28s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.4233 - accuracy: 0.9201 - val_loss: 1.4009 - val_accuracy: 0.5677
# Epoch 86/100
# 9/9 [==============================] - 29s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.1856 - accuracy: 0.9583 - val_loss: 1.8354 - val_accuracy: 0.6302
# Epoch 87/100
# 9/9 [==============================] - 29s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.2893 - accuracy: 0.9297 - val_loss: 1.5702 - val_accuracy: 0.5469
# Epoch 88/100
# 9/9 [==============================] - 28s 4s/step - batch: 4.0000 - size: 128.0000 - loss: 0.2955 - accuracy: 0.9201 - val_loss: 3.0204 - val_accuracy: 0.5755
# CPU times: total: 1h 23min 50s
# Wall time: 42min 46s

# %%
history1.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# let's plot the loss and accuracy 

# get the training and validation accuracy from the history object
train_acc = history1.history['accuracy']
valid_acc = history1.history['val_accuracy']

# get the loss
train_loss = history1.history['loss']
valid_loss = history1.history['val_loss']

# get the number of entries
xvalues = np.arange(len(train_acc))

# visualize
f,ax = plt.subplots(1,2, figsize=(10,5))
ax[0].plot(xvalues, train_loss)
ax[0].plot(xvalues, valid_loss)
ax[0].set_title("Loss curve")
ax[0].set_xlabel("Epoch")
ax[0].set_ylabel("loss")
ax[0].legend(['train', 'validation'])

ax[1].plot(xvalues, train_acc)
ax[1].plot(xvalues, valid_acc)
ax[1].set_title("Accuracy")
ax[1].set_xlabel("Epoch")
ax[1].set_ylabel("accuracy")
ax[1].legend(['train', 'validation'])

plt.show()

# %%
# What is the final loss and accuracy on our validation data?
valid_loss, valid_acc = model.evaluate_generator(valid_data_gen, steps=num_valid_steps)
print(f"Final validation accuracy: {valid_acc*100:.2f}%")
# Out:
# Final validation accuracy: 61.72%

# %%
outputs = [layer.output for layer in model.layers[1:18]]

vis_model = Model(model.input, outputs)

for layer in vis_model.layers:
  layer.trainable = False

vis_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 224, 224, 16)      208
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 32)      2080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 56, 56, 64)        8256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 128)       32896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 14, 14, 256)       131328
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 12544)             0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              51384320
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                40970
# =================================================================
# Total params: 68,381,370
# Trainable params: 0
# Non-trainable params: 68,381,370
# _________________________________________________________________

# %%
# store the layer names we are interested in
layer_names = []
for layer in outputs:
    layer_names.append(layer.name.split("/")[0])

    
print("Layers going to be used for visualization: ")
print(layer_names)
# Out:
# Layers going to be used for visualization:
# ['conv2d', 'max_pooling2d', 'conv2d_1', 'max_pooling2d_1', 'conv2d_2', 'max_pooling2d_2', 'conv2d_3', 'max_pooling2d_3', 'conv2d_4', 'max_pooling2d_4', 'flatten', 'dense', 'dense_1', 'dropout', 'dense_2']

# %%
print( f'layer_names [before]: {layer_names}' )

layer_names_temp = layer_names
layer_names = list()
for layer in layer_names_temp:

  if 'conv' in layer:
    # print(layer)
    layer_names.append( layer )

print( '=========================================' )
print( f'layer_names [after]: {layer_names}' )
# Out:
# layer_names [before]: ['conv2d', 'max_pooling2d', 'conv2d_1', 'max_pooling2d_1', 'conv2d_2', 'max_pooling2d_2', 'conv2d_3', 'max_pooling2d_3', 'conv2d_4', 'max_pooling2d_4', 'flatten', 'dense', 'dense_1', 'dropout', 'dense_2']
# =========================================
# layer_names [after]: ['conv2d', 'conv2d_1', 'conv2d_2', 'conv2d_3', 'conv2d_4']

# %%
def get_CAM(processed_image, predicted_label):
    """
    This function is used to generate a heatmap for a sample image prediction.
    
    Args:
        processed_image: any sample image that has been pre-processed using the 
                       `preprocess_input()`method of a keras model
        predicted_label: label that has been predicted by the network for this image
    
    Returns:
        heatmap: heatmap generated over the last convolution layer output 
    """
    # we want the activations for the predicted label
    predicted_output = model.output[:, predicted_label]
    
    # choose the last conv layer in your model
    # last_conv_layer = model.get_layer('block5_conv3')
    last_conv_layer = model.get_layer(layer_names[-1])
    
    # get the gradients wrt to the last conv layer
    grads = K.gradients(predicted_output, last_conv_layer.output)[0]
    
    # take mean gradient per feature map
    grads = K.mean(grads, axis=(0,1,2)) # GAP - Global Average Pooling
    
    # Define a function that generates the values for the output and gradients
    evaluation_function = K.function([model.input], [grads, last_conv_layer.output[0]])
    
    # get the values
    grads_values, conv_ouput_values = evaluation_function([processed_image])
    
    # CAM - Class Activation Map
    # iterate over each feature map in yout conv output and multiply
    # the gradient values with the conv output values. This gives an 
    # indication of "how important a feature is"
    # for i in range(512): # we have 512 features in our last conv layer
    for i in range(conv_ouput_values.shape[2]): # daniel
        conv_ouput_values[:,:,i] *= grads_values[i]
    
    # create a heatmap
    heatmap = np.mean(conv_ouput_values, axis=-1)
    
    # remove negative values
    heatmap = np.maximum(heatmap, 0)
    
    # normalize
    heatmap /= heatmap.max()
    
    return heatmap

# %%
idx = 0

# %%
# select the sample and read the corresponding image and label
sample_image = cv2.imread(valid_df.iloc[idx]['image'])
sample_image = cv2.cvtColor(sample_image, cv2.COLOR_BGR2RGB)
sample_image = cv2.resize(sample_image, (img_rows, img_cols))
sample_label = valid_df.iloc[idx]["label"]

# pre-process the image
sample_image_processed = np.expand_dims(sample_image, axis=0)
sample_image_processed = preprocess_input(sample_image_processed)

# get the label predicted by our original model
pred_label = np.argmax(model.predict(sample_image_processed), axis=-1)[0]

# get the heatmap for class activation map(CAM)
heatmap = get_CAM(sample_image_processed, pred_label)
heatmap = cv2.resize(heatmap, (sample_image.shape[0], sample_image.shape[1]))
heatmap = heatmap *255
heatmap = np.clip(heatmap, 0, 255).astype(np.uint8)
heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
super_imposed_image = heatmap * 0.5 + sample_image
super_imposed_image = np.clip(super_imposed_image, 0,255).astype(np.uint8)

# Ploting
fontsize = 10
fig, axes = plt.subplots( 1, 3, figsize=( 8, 8 ) )
axes[0].set_title( f'True label: {sample_label} \n Predicted label: {pred_label}',
                  fontsize = fontsize )
axes[0].axis('off')
axes[0].imshow( sample_image )

axes[1].set_title( f'Class Activation Map',
                  fontsize = fontsize )
axes[1].axis('off')
axes[1].imshow( heatmap )

axes[2].set_title( f'Activation Map Superimposed',
                  fontsize = fontsize )
axes[2].axis('off')
axes[2].imshow( super_imposed_image )
plt.show()

# # Plot just CAM of the layer
# plt.figure( figsize=(2, 2) )
# plt.title( f'Class Activation Map - Layer: {layer}' )
# plt.imshow( heatmap )
# plt.show()
# Out:
# C:\Users\danie\anaconda3\envs\tf\lib\site-packages\keras\engine\training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
